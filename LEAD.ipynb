# %% [markdown]
# <a href="https://colab.research.google.com/github/gniman/PythonProject/blob/master/LEAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing numpy and pandas
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1K9jFkJ1SXHrcACJ7XrTlfEReQ38D2ibZ/view?usp=sharing'
file_id = url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(dwn_url)

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
df.shape
# Out:
# (9240, 37)

# %% [markdown]
# ***DATA PREPARATION***

# %%
# Checking column with 'Select' field
# 'Select' is an option that was not selected during data entry
df.columns[df.isin(['Select']).any()]
# Out:
# Index(['Specialization', 'How did you hear about X Education', 'Lead Profile',
#        'City'],
#       dtype='object')

# %%
# # replacing 'Select' by nan in 'Specialization','city','education', 'how did you hear abput x education'
# df['Specialization'] = df['Specialization'].replace(np.nan, 'Select', inplace = True)
# df['Lead Profile'] = df['Lead Profile'].replace(np.nan, 'Select', inplace = True)
# df['City'] = df['City'].replace(np.nan, 'Select', inplace = True)
# df['How did you hear about X Education'] = df['How did you hear about X Education'].replace(np.nan, 'Select', inplace = True)

df = df.replace(to_replace= 'Select', value = np.nan)
df = df.replace(to_replace= 'Lead Profile', value = np.nan)
df = df.replace(to_replace= 'City', value = np.nan)
df = df.replace(to_replace= 'How did you hear about X Education', value = np.nan)

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# checking the percentage of missing values
round(df.isnull().sum()/len(df),2)
# Out:
# Prospect ID                                      0.00
# Lead Number                                      0.00
# Lead Origin                                      0.00
# Lead Source                                      0.00
# Do Not Email                                     0.00
# Do Not Call                                      0.00
# Converted                                        0.00
# TotalVisits                                      0.01
# Total Time Spent on Website                      0.00
# Page Views Per Visit                             0.01
# Last Activity                                    0.01
# Country                                          0.27
# Specialization                                   0.37
# How did you hear about X Education               0.78
# What is your current occupation                  0.29
# What matters most to you in choosing a course    0.29
# Search                                           0.00
# ...

# %%
#replacing 'Select' by nan in 'City'

df['City'] = df['City'].replace(np.nan, 'Select')

# %%
df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
df = df.drop ('Lead Profile', axis = 1)
df = df.drop ('Prospect ID', axis = 1)
df = df.drop ('Lead Quality', axis = 1)
df = df.drop ('How did you hear about X Education', axis = 1)
df = df.drop ('Country', axis = 1)
df = df.drop ('Specialization', axis = 1)
df = df.drop ('What is your current occupation', axis = 1)
df = df.drop ('What matters most to you in choosing a course', axis = 1)
df = df.drop ('Tags', axis = 1)
df = df.drop ('Asymmetrique Activity Index', axis = 1)
df = df.drop ('Asymmetrique Profile Index', axis = 1)
df = df.drop ('Asymmetrique Activity Score', axis = 1)
df = df.drop ('Asymmetrique Profile Score', axis = 1)

# %%
df.head()
df.shape
# Out:
# (9240, 24)

# %%
# looking at skewness of columns with categorical data
(df['Do Not Call'].value_counts()/9240)*100
# Out:
# No     99.978355
# Yes     0.021645
# Name: Do Not Call, dtype: float64

# %%
# looking at skewness of columns with categorical data
(df['Converted'].value_counts()/9240)*100
# Out:
# 0    61.461039
# 1    38.538961
# Name: Converted, dtype: float64

# %%
# Calculate the percentage of each category
percentage_df = (df['Converted'].value_counts() / 9240) * 100

# Create the bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=percentage_df.index, y=percentage_df.values, palette='pastel')

# Customize the plot
plt.title("Percentage of Converted (0 and 1)", fontsize=16)
plt.xlabel("Converted", fontsize=14)
plt.ylabel("Percentage", fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage')

# %%
# looking at skewness of columns with categorical data
(df['Search'].value_counts()/9240)*100
# Out:
# No     99.848485
# Yes     0.151515
# Name: Search, dtype: float64

# %%
df = df.drop('Search', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Magazine'].value_counts()/9240)*100
# Out:
# No    100.0
# Name: Magazine, dtype: float64

# %%
df = df.drop('Magazine', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Newspaper Article'].value_counts()/9240)*100
# Out:
# No     99.978355
# Yes     0.021645
# Name: Newspaper Article, dtype: float64

# %%
df = df.drop('Newspaper Article', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['X Education Forums'].value_counts()/9240)*100
# Out:
# No     99.989177
# Yes     0.010823
# Name: X Education Forums, dtype: float64

# %%
df = df.drop('X Education Forums', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Newspaper'].value_counts()/9240)*100
# Out:
# No     99.989177
# Yes     0.010823
# Name: Newspaper, dtype: float64

# %%
df = df.drop('Newspaper', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Digital Advertisement'].value_counts()/9240)*100
# Out:
# No     99.95671
# Yes     0.04329
# Name: Digital Advertisement, dtype: float64

# %%
df = df.drop('Digital Advertisement', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Through Recommendations'].value_counts()/9240)*100
# Out:
# No     99.924242
# Yes     0.075758
# Name: Through Recommendations, dtype: float64

# %%
df = df.drop('Through Recommendations', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['Receive More Updates About Our Courses'].value_counts()/9240)*100
# Out:
# No    100.0
# Name: Receive More Updates About Our Courses, dtype: float64

# %%
# looking at skewness of columns with categorical data
(df['Update me on Supply Chain Content'].value_counts()/9240)*100
# Out:
# No    100.0
# Name: Update me on Supply Chain Content, dtype: float64

# %%
# looking at skewness of columns with categorical data
(df['Get updates on DM Content'].value_counts()/9240)*100
# Out:
# No    100.0
# Name: Get updates on DM Content, dtype: float64

# %%
# looking at skewness of columns with categorical data
(df['I agree to pay the amount through cheque'].value_counts()/9240)*100
# Out:
# No    100.0
# Name: I agree to pay the amount through cheque, dtype: float64

# %%
df = df.drop('I agree to pay the amount through cheque', axis = 1)

# %%
# looking at skewness of columns with categorical data
(df['A free copy of Mastering The Interview'].value_counts()/9240)*100
# Out:
# No     68.744589
# Yes    31.255411
# Name: A free copy of Mastering The Interview, dtype: float64

# %%
df.skew()
# Out:
# <ipython-input-143-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Lead Number                     0.140451
# Converted                       0.471058
# TotalVisits                    19.911657
# Total Time Spent on Website     0.956450
# Page Views Per Visit            2.871793
# dtype: float64

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit
# count           9103.000000
# mean               2.362820
# std                2.161418
# min                0.000000
# 25%                1.000000
# 50%                2.000000
# 75%                3.000000
# max               55.000000

# %%
graph1 = (df['Last Notable Activity'].value_counts()/9240)*100
graph1
# Out:
# Modified                        36.872294
# Email Opened                    30.595238
# SMS Sent                        23.506494
# Page Visited on Website          3.441558
# Olark Chat Conversation          1.980519
# Email Link Clicked               1.872294
# Email Bounced                    0.649351
# Unsubscribed                     0.508658
# Unreachable                      0.346320
# Had a Phone Conversation         0.151515
# Email Marked Spam                0.021645
# Approached upfront               0.010823
# Resubscribed to emails           0.010823
# View in browser link Clicked     0.010823
# Form Submitted on Website        0.010823
# Email Received                   0.010823
# Name: Last Notable Activity, dtype: float64

# %%
def test(x):
  if x == 'Modified' or x == 'Email Opened' or x == 'SMS Sent':
    return x
  else:
    return 'Other'

# %%
df ['Last Notable Activity']= df['Last Notable Activity'].apply(test)

# %%
graph2 = (df['Lead Source'].value_counts()/9240)*100
graph2
# Out:
# Google               31.038961
# Direct Traffic       27.521645
# Olark Chat           18.993506
# Organic Search       12.489177
# Reference             5.779221
# Welingak Website      1.536797
# Referral Sites        1.352814
# Facebook              0.595238
# bing                  0.064935
# google                0.054113
# Click2call            0.043290
# Press_Release         0.021645
# Social Media          0.021645
# Live Chat             0.021645
# youtubechannel        0.010823
# testone               0.010823
# Pay per Click Ads     0.010823
# welearnblog_Home      0.010823
# WeLearn               0.010823
# blog                  0.010823
# NC_EDM                0.010823
# Name: Lead Source, dtype: float64

# %%
def leadsource(x):
  if x == 'Google' or x == 'Direct Traffic' or x == 'Olark Chat' or x == 'Organic Search':
    return x
  else:
    return 'Other'

# %%
df ['Lead Source']= df['Lead Source'].apply(leadsource)

# %%
df.head()
# Out:
#    Lead Number              Lead Origin     Lead Source Do Not Email  \
# 0       660737                      API      Olark Chat           No
# 1       660728                      API  Organic Search           No
# 2       660727  Landing Page Submission  Direct Traffic           No
# 3       660719  Landing Page Submission  Direct Traffic           No
# 4       660681  Landing Page Submission          Google           No
#
#   Do Not Call  Converted  TotalVisits  Total Time Spent on Website  \
# 0          No          0          0.0                            0
# 1          No          0          5.0                          674
# 2          No          1          2.0                         1532
# 3          No          0          1.0                          305
# 4          No          1          2.0                         1428
#
#    Page Views Per Visit            Last Activity  \
# 0                   0.0  Page Visited on Website
# ...

# %%
graph1 = (df['TotalVisits'].value_counts()/9240)*100
sns.distplot(graph1)
plt.show()
graph1
# Out:
# <ipython-input-152-49cc7e6ffa83>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(graph1)
# 0.0      23.690476
# 2.0      18.181818
# 3.0      14.134199
# 4.0      12.121212
# 5.0       8.474026
# 6.0       5.043290
# 1.0       4.274892
# 7.0       3.344156
# 8.0       2.424242
# 9.0       1.774892
# 10.0      1.233766
# 11.0      0.930736
# 13.0      0.519481
# 12.0      0.487013
# 14.0      0.389610
# 16.0      0.227273
# 15.0      0.194805
# 17.0      0.173160
# 18.0      0.162338
# 20.0      0.129870
# 19.0      0.097403
# 21.0      0.064935
# 23.0      0.064935
# 24.0      0.054113
# 25.0      0.054113
# ...

# %%
# df = df.drop('TotalVisits', axis = 1)

# %%
df.head()
# Out:
#    Lead Number              Lead Origin     Lead Source Do Not Email  \
# 0       660737                      API      Olark Chat           No
# 1       660728                      API  Organic Search           No
# 2       660727  Landing Page Submission  Direct Traffic           No
# 3       660719  Landing Page Submission  Direct Traffic           No
# 4       660681  Landing Page Submission          Google           No
#
#   Do Not Call  Converted  TotalVisits  Total Time Spent on Website  \
# 0          No          0          0.0                            0
# 1          No          0          5.0                          674
# 2          No          1          2.0                         1532
# 3          No          0          1.0                          305
# 4          No          1          2.0                         1428
#
#    Page Views Per Visit            Last Activity  \
# 0                   0.0  Page Visited on Website
# ...

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (9103, 16)

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9103.000000  9103.000000  9103.000000                  9103.000000
# mean   617027.742612     0.380204     3.445238                   481.350104
# std     23337.138926     0.485464     4.854853                   545.066142
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596408.000000     0.000000     1.000000                     9.000000
# 50%    615278.000000     0.000000     3.000000                   244.000000
# 75%    637166.000000     1.000000     5.000000                   919.500000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit
# count           9103.000000
# mean               2.362820
# std                2.161418
# min                0.000000
# 25%                1.000000
# 50%                2.000000
# 75%                3.000000
# max               55.000000

# %%
df['TotalVisits'].quantile(0.999)
# Out:
# 31.796000000002095

# %%
# Step 1: Find the index of rows where 'TotalVisits' is equal to 10
rows_to_remove = df[df['TotalVisits'] >=26.908000000001266 ].index

# Step 2: Use the 'drop()' method with the 'index' parameter to remove the rows directly from 'df'
df.drop(index=rows_to_remove, inplace=True)

# %%
df.shape
# Out:
# (9083, 16)

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9083.000000  9083.000000  9083.000000                  9083.000000
# mean   617042.019047     0.380601     3.328746                   481.511175
# std     23341.262417     0.485561     3.323198                   545.363050
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596416.500000     0.000000     1.000000                     8.000000
# 50%    615283.000000     0.000000     3.000000                   244.000000
# 75%    637170.500000     1.000000     5.000000                   920.500000
# max    660737.000000     1.000000    26.000000                  2272.000000
#
#        Page Views Per Visit
# count           9083.000000
# mean               2.351251
# std                2.081696
# min                0.000000
# 25%                1.000000
# 50%                2.000000
# 75%                3.000000
# max               24.000000

# %%
df['Total Time Spent on Website'].quantile(0.99)
# Out:
# 1839.0

# %%
# Step 1: Find the index of rows where 'TotalVisits' is equal to 10
rows_to_remove = df[df['Total Time Spent on Website'] >=1839.8199999999997].index

# Step 2: Use the 'drop()' method with the 'index' parameter to remove the rows directly from 'df'
df.drop(index=rows_to_remove, inplace=True)

# %%
df.shape
# Out:
# (8993, 16)

# %%
df['Page Views Per Visit'].quantile(0.999)
# Out:
# 14.0

# %%
# Step 1: Find the index of rows where 'TotalVisits' is equal to 10
rows_to_remove = df[df['Page Views Per Visit'] >=12.0].index

# Step 2: Use the 'drop()' method with the 'index' parameter to remove the rows directly from 'df'
df.drop(index=rows_to_remove, inplace=True)

# %%
df.shape
# Out:
# (8965, 16)

# %%
df['Lead Number'].quantile(0.99)
# Out:
# 659563.8

# %%
# Step 1: Find the index of rows where 'TotalVisits' is equal to 10
rows_to_remove = df[df['Lead Number'] >=659600.21].index

# Step 2: Use the 'drop()' method with the 'index' parameter to remove the rows directly from 'df'
df.drop(index=rows_to_remove, inplace=True)

# %%
df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    8878.000000  8878.000000  8878.000000                  8878.000000
# mean   616632.797477     0.377788     3.272246                   465.415409
# std     23033.425822     0.484861     3.256746                   527.151288
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596258.000000     0.000000     1.000000                     5.000000
# 50%    614908.500000     0.000000     3.000000                   238.000000
# 75%    636631.000000     1.000000     5.000000                   886.000000
# max    659600.000000     1.000000    26.000000                  1839.000000
#
#        Page Views Per Visit
# count           8878.000000
# mean               2.301057
# std                1.972456
# min                0.000000
# 25%                1.000000
# 50%                2.000000
# 75%                3.000000
# max               11.500000

# %%
df['Page Views Per Visit'].quantile(0.989)
# Out:
# 8.0

# %%
# Step 1: Find the index of rows where 'TotalVisits' is equal to 10
rows_to_remove = df[df['Page Views Per Visit'] >= 7.0].index

# Step 2: Use the 'drop()' method with the 'index' parameter to remove the rows directly from 'df'
df.drop(index=rows_to_remove, inplace=True)

# %%
df.shape
# Out:
# (8575, 16)

# %%
df.head()
# Out:
#     Lead Number              Lead Origin     Lead Source Do Not Email  \
# 92       659600  Landing Page Submission          Google           No
# 93       659582  Landing Page Submission          Google           No
# 94       659567  Landing Page Submission  Direct Traffic           No
# 95       659562  Landing Page Submission  Direct Traffic           No
# 96       659555  Landing Page Submission          Google           No
#
#    Do Not Call  Converted  TotalVisits  Total Time Spent on Website  \
# 92          No          0          4.0                          101
# 93          No          0          9.0                          838
# 94          No          0          3.0                          536
# 95          No          0          4.0                          161
# 96          No          0          2.0                          511
#
#     Page Views Per Visit              Last Activity  \
# 92                   4.0               Email Opened
# ...

# %%
df.head()
# Out:
#     Lead Number              Lead Origin     Lead Source Do Not Email  \
# 92       659600  Landing Page Submission          Google           No
# 93       659582  Landing Page Submission          Google           No
# 94       659567  Landing Page Submission  Direct Traffic           No
# 95       659562  Landing Page Submission  Direct Traffic           No
# 96       659555  Landing Page Submission          Google           No
#
#    Do Not Call  Converted  TotalVisits  Total Time Spent on Website  \
# 92          No          0          4.0                          101
# 93          No          0          9.0                          838
# 94          No          0          3.0                          536
# 95          No          0          4.0                          161
# 96          No          0          2.0                          511
#
#     Page Views Per Visit              Last Activity  \
# 92                   4.0               Email Opened
# ...

# %%
df
# Out:
#       Lead Number              Lead Origin     Lead Source Do Not Email  \
# 92         659600  Landing Page Submission          Google           No
# 93         659582  Landing Page Submission          Google           No
# 94         659567  Landing Page Submission  Direct Traffic           No
# 95         659562  Landing Page Submission  Direct Traffic           No
# 96         659555  Landing Page Submission          Google           No
# ...           ...                      ...             ...          ...
# 9234       579615  Landing Page Submission  Direct Traffic           No
# 9236       579546  Landing Page Submission  Direct Traffic           No
# 9237       579545  Landing Page Submission  Direct Traffic          Yes
# 9238       579538  Landing Page Submission          Google           No
# 9239       579533  Landing Page Submission  Direct Traffic           No
#
#      Do Not Call  Converted  TotalVisits  Total Time Spent on Website  \
# ...

# %%
leadorigindummy = pd.get_dummies(df['Lead Origin'])
leadsourcedummy = pd.get_dummies(df['Lead Source'])
notabledummy = pd.get_dummies(df['Last Notable Activity'])
lastactivitydummy = pd.get_dummies(df['Last Activity'])

# %%
df = df.drop(['Lead Origin', 'Lead Source', 'Last Activity', 'Last Notable Activity'], axis = 1)

# %%
def Do_Not_Email(x):
  if x == 'No':
    return 0
  elif x =='Yes':
    return 1

# %%
df['A free copy of Mastering The Interview'] = df['A free copy of Mastering The Interview'].apply(Do_Not_Email)
df ['Do Not Email']= df['Do Not Email'].apply(Do_Not_Email)
df ['Do Not Call']= df['Do Not Call'].apply(Do_Not_Email)
df ['Receive More Updates About Our Courses']= df['Receive More Updates About Our Courses'].apply(Do_Not_Email)
df ['Get updates on DM Content']= df['Get updates on DM Content'].apply(Do_Not_Email)
df ['Update me on Supply Chain Content']= df['Update me on Supply Chain Content'].apply(Do_Not_Email)

# %%
def city (x):
    if  x == 'Select':
        return 'select_city'
    else:
        return x

# %%
df['City'] = df['City'].apply(city)

# %%
citydummy = pd.get_dummies(df['City'], drop_first = True)
citydummy.head()
# Out:
#     Other Cities  Other Cities of Maharashtra  Other Metro Cities  \
# 92             0                            0                   0
# 93             0                            0                   0
# 94             0                            0                   0
# 95             0                            0                   0
# 96             0                            0                   0
#
#     Thane & Outskirts  Tier II Cities  select_city
# 92                  0               0            0
# 93                  0               0            0
# 94                  0               0            0
# 95                  0               0            1
# 96                  0               0            0

# %%
final = pd.concat([df, leadorigindummy, leadsourcedummy, notabledummy, lastactivitydummy, citydummy], axis = 1)

# %%
final.describe()
# Out:
#          Lead Number  Do Not Email  Do Not Call    Converted  TotalVisits  \
# count    8575.000000   8575.000000  8575.000000  8575.000000  8575.000000
# mean   616610.850845      0.078484     0.000233     0.377726     3.086181
# std     23000.046903      0.268947     0.015271     0.484847     3.120870
# min    579533.000000      0.000000     0.000000     0.000000     0.000000
# 25%    596238.000000      0.000000     0.000000     0.000000     0.000000
# 50%    614930.000000      0.000000     0.000000     0.000000     3.000000
# 75%    636462.000000      0.000000     0.000000     1.000000     4.000000
# max    659600.000000      1.000000     1.000000     1.000000    26.000000
#
#        Total Time Spent on Website  Page Views Per Visit  \
# count                  8575.000000            8575.00000
# mean                    460.447813               2.09807
# std                     526.550085               1.66423
# min                       0.000000               0.00000
# ...

# %%
# importing relevant libraries

import sklearn
from sklearn.model_selection import train_test_split

# %%
final_train, final_test = train_test_split(final, train_size = 0.7, random_state = 100)

print(final_train.shape)
print(final_test.shape)
# Out:
# (6002, 48)
# (2573, 48)

# %%
#importing relevant packages

from sklearn.preprocessing import MinMaxScaler

# %%
# Instiating scaler object

scaler = MinMaxScaler()

# %%
# creating a list of numeric variables

numeric = ['TotalVisits','Total Time Spent on Website','Page Views Per Visit']

# %%
final_train[numeric] = scaler.fit_transform(final_train[numeric])

# %%
final_train.head()
# Out:
#       Lead Number  Do Not Email  Do Not Call  Converted  TotalVisits  \
# 8537       584561             0            0          0     0.384615
# 7356       593016             0            0          1     0.000000
# 7707       590711             0            0          1     0.153846
# 189        658531             0            0          1     0.230769
# 4968       612288             0            0          1     0.115385
#
#       Total Time Spent on Website  Page Views Per Visit  \
# 8537                     0.727026              0.769231
# 7356                     0.000000              0.000000
# 7707                     0.817292              0.307692
# 189                      0.209353              0.923077
# 4968                     0.560631              0.461538
#
#       Receive More Updates About Our Courses  \
# 8537                                       0
# 7356                                       0
# 7707                                       0
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
# dividing the data into train and test split

final_train, final_test = train_test_split(final, train_size = 0.7, random_state = 100)
print(final_train.shape)
print(final_test.shape)
# Out:
# (6002, 48)
# (2573, 48)

# %%
x = final.drop(['Lead Number','Converted', 'City'], axis =1)

# %%
y = final['Converted']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
# calculating the conversion rate

conversion = sum(final['Converted'])/len(final['Converted'].index)
conversion
# Out:
# 0.3777259475218659

# %% [markdown]
# BUILDING A FIRST MODEL

# %%
import statsmodels.api as sm

# %%
x_train = x_train.replace([np.inf, -np.inf], np.nan).dropna()
y_train = y_train.loc[x_train.index]

# %%
model = sm.GLM(y_train, (sm.add_constant(x_train)), family = sm.families.Binomial())

# %%
# importing relevant libraries

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
# running Recursive Feature Elimination (RFE)

from sklearn.feature_selection import RFE
rfe = RFE(estimator=logreg, n_features_to_select = 10)

rfe = rfe.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# creating a list of all the variables and their RFE rankings

list(zip(x_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('Do Not Email', True, 1),
#  ('Do Not Call', False, 12),
#  ('TotalVisits', False, 21),
#  ('Total Time Spent on Website', False, 31),
#  ('Page Views Per Visit', False, 20),
#  ('Receive More Updates About Our Courses', False, 36),
#  ('Update me on Supply Chain Content', False, 35),
#  ('Get updates on DM Content', False, 34),
#  ('A free copy of Mastering The Interview', False, 13),
#  ('API', False, 14),
#  ('Landing Page Submission', True, 1),
#  ('Lead Add Form', True, 1),
#  ('Lead Import', False, 4),
#  ('Direct Traffic', False, 29),
#  ('Google', False, 17),
#  ('Olark Chat', False, 27),
#  ('Organic Search', False, 22),
#  ('Other', False, 28),
#  ('Email Opened', False, 8),
#  ('Modified', False, 7),
#  ('Other', False, 16),
#  ('SMS Sent', True, 1),
#  ('Approached upfront', True, 1),
#  ('Converted to Lead', True, 1),
#  ('Email Bounced', False, 2),
#  ('Email Link Clicked', False, 5),
#  ('Email Marked Spam', False, 15),
#  ('Email Opened', False, 26),
# ...

# %%
# storing the selected columns in col

col = x_train.columns[rfe.support_]

# %%
# chekcking the selected columns

x_train.columns[rfe.support_]
# Out:
# Index(['Do Not Email', 'Landing Page Submission', 'Lead Add Form', 'SMS Sent',
#        'Approached upfront', 'Converted to Lead', 'Form Submitted on Website',
#        'Had a Phone Conversation', 'Olark Chat Conversation', 'select_city'],
#       dtype='object')

# %%
# creating the model

x_train_sm = sm.add_constant(x_train[col])
model_one = sm.GLM(y_train, x_train_sm, family = sm.families.Binomial())
model_one.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Converted   No. Observations:                 6002
# Model:                            GLM   Df Residuals:                     5990
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3101.9
# Date:                Mon, 14 Aug 2023   Deviance:                       6203.8
# Time:                        06:04:23   Pearson chi2:                 6.30e+03
# No. Iterations:                    20   Pseudo R-squ. (CS):             0.2549
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
# importing relevant libraries

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# creating a new dataframe that consists of the name of the variables and their respective VIF

vif = pd.DataFrame()

# assigning the column 'variables' with the columns of X_train

vif['variables'] = x_train[col].columns

# assigning the column 'VIF' with the VIF values of the variales

vif['VIF'] = [variance_inflation_factor(x_train[col].values,i) for i in range (x_train[col].shape[1])]

# rounding off the VIF values to 2 decimal places

vif['VIF'] = round(vif['VIF'],2)

# sorting the VIF values in descending order

vif = vif.sort_values(by = 'VIF' , ascending = False)

# printing the dataframe vif

vif
# Out:
#                     variables   VIF
# 4                    SMS Sent  5.34
# 3                    SMS Sent  4.74
# 10                select_city  1.72
# 1     Landing Page Submission  1.50
# 9     Olark Chat Conversation  1.36
# 2               Lead Add Form  1.16
# 0                Do Not Email  1.10
# 6           Converted to Lead  1.10
# 7   Form Submitted on Website  1.02
# 8    Had a Phone Conversation  1.01
# 5          Approached upfront  1.00

# %%
new = x_train[col]

# %%
new.drop('Other_lp', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-211-43f9dc7809a2> in <cell line: 1>()
# ----> 1 new.drop('Other_lp', axis = 1, inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
x_train_sm = sm.add_constant(new)
model_one = sm.GLM(y_train, x_train_sm, family = sm.families.Binomial())
pred = model_one.fit()
pred.summary()
